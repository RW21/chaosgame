# %%
import ipyvolume as ipv
import numpy as np
import chaos_game as cg
from scipy.constants import constants

# %%
demo_1 = cg.ChaosGameRegularPolyhedra(4)

demo_1.chaos_game(25000, 1/2)

x, y, z = np.array(demo_1.x), np.array(demo_1.y), np.array(demo_1.z)

ipv.quickscatter(x, y, z, size=0.5, marker="sphere")
# Out:
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %%
demo_2 = cg.ChaosGameRegularPolygon(4)
demo_2.add_virtual_vertex(1)
demo_2.chaos_game(10000, 2/3)
demo_2.generate_heatmap()
# Out:
# <module 'matplotlib.pyplot' from '/Users/rinzewatanabe/Documents/fractals/venv/lib/python3.8/site-packages/matplotlib/pyplot.py'>
